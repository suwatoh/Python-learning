# %% [markdown]
# <a href="https://colab.research.google.com/github/suwatoh/Python-learning/blob/main/000_%E3%81%AF%E3%81%98%E3%82%81%E3%81%AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# これは、私@suwatohが Python の[公式チュートリアル](https://docs.python.org/ja/3/tutorial/index.html)を読み終わった後に、さらに深掘りして得た情報を書き留めたノートです。
#
# ノート作成時点でサポートが終了していた Python 3.7 以前の事柄は切り捨てています。ノート作成時点の最新 Python バージョンは 3.12 でしたが、Colab で動作する Python バージョンは 3.10 でした。
#
# コードは空行などについて PEP 8 に従っていない書き方をしている場合があります。
#
# 1xx 接頭辞が付いた名前のノートは、主に Python の言語機能や標準ライブラリに関する内容です。いくつかのサードパーティ製のパッケージに関する内容も含んでいます。また、開発環境やオープンソースライセンスに関する内容も含んでいます。
#
# 2xx 接頭辞が付いた名前のノートは、主要なサードパーティ製のパッケージに関する内容です。
#
# 所詮初学者がまとめたノートなので、間違いが多分に含まれていると思います。
#
# 変更履歴:
#
#   - 2025/06/16  Python 3.13 対応
#
# 参考書籍・サイトは以下のとおりです。
#
# 技術評論社
# [Pythonエンジニア育成推進協会監修 Python実践レシピ](https://gihyo.jp/book/2022/978-4-297-12576-9)
#
# gihyo.jp
# [新しい静的コード解析ツール「Ruff」をご紹介](https://gihyo.jp/article/2023/03/monthly-python-2303)
# [Python最新バージョン対応！より良い型ヒントの書き方](https://gihyo.jp/article/2022/09/monthly-python-2209)
# [HTTP/3入門 第1章 進化するHTTPの歩み ～ HTTP/1.1とHTTP/2をおさらいし⁠⁠、HTTP/3の基本を知る](https://gihyo.jp/admin/serial/01/http3/0001)
# [Python 3.11の新機能：asyncio.TaskGroupを使った予測可能でより安全な非同期処理](https://gihyo.jp/article/2022/10/monthly-python-2210)
# [テストダブル～忠実性と決定性のトレードオフを理解する～](https://gihyo.jp/dev/serial/01/savanna-letter/0004)
# [自動テストのサイズダウン戦略～テストダブルを作る前に考えるべきこと～](https://gihyo.jp/dev/serial/01/savanna-letter/0006)
#
# POSTD
# [Pythonのオブジェクトとクラスのビジュアルガイド – 全てがオブジェクトであるということ](https://postd.cc/pythons-objects-and-classes-a-visual-guide/)
# [Pythonの新しい文字列フォーマット : %記号、str.format()から文字列補完へ](https://postd.cc/new-string-formatting-in-python/)
# [正規表現：悪い表現、いい表現、最良の表現](https://postd.cc/regexes-the-bad-the-better-and-the-best/)
#
# @PoodleMaster(ぽむた)さんの Qiita 記事
# [グチャグチャになった「Ubuntu on WSL2」のやり直し方](https://qiita.com/PoodleMaster/items/b54db3608c4d343d27c4)
#
# NIFTY engineering Blog
# [コンテナによるローカル開発環境 その2(Dev Containers編)](https://engineering.nifty.co.jp/blog/24158)
#
# 豆蔵デベロッパーサイト
# [【devcontainer完全ガイド】DockerとWSLで最強のイマドキ開発環境を手に入れよう！](https://developer.mamezou-tech.com/blogs/2024/10/11/devcontainer/)
#
# trivial technologies
# [和訳 なぜPythonのメソッド引数に明示的にselfと書くのか](https://coreblog.org/ats/translation-of-why-explicit-self-has-to-stay/)
#
# Think IT
# [今さら聞けない！ゼロから学ぶオブジェクト指向](https://thinkit.co.jp/series/6932)
#
# よしたろうブログの記事
# [「初心者のためのデザインパターン入門」シリーズ 第0回 【デザインパターンとは？】](https://yoshitaro-yoyo.hatenablog.com/entry/What_is_a_design_pattern/2022/08/16/181300)
#
# ecbeing labs
# [なぜあんなに難しい？Factory Methodパターン](https://blog.ecbeing.tech/entry/2021/01/20/114000)
#
# @hankehlyさんの Qiita 記事
# [【Strategyパターン】すべての開発者が知っておくべき強力なツール](https://qiita.com/hankehly/items/1848f2fd8e09812d1aaf)
#
# @mootaro1さんの YouTube チャンネル
# [Python - ジェネレータ ( Generator ) の理解と実装](https://www.youtube.com/playlist?list=PLti9_b53ViKdm1-mKRYRfd1zpE5JvGccn)
# [Python - デコレーター ( Decorator ) の動作理解と実装](https://www.youtube.com/playlist?list=PLti9_b53ViKfGMSrhocZTYRVuLJGMZldV)
#
# くろのてさんの記事
# [[Python] 怖くない！デコレータ](https://note.crohaco.net/2014/python-decorator/)
#
# Python.jp
# [Python 3.11の新機能(その4）PEP 654 例外グループとTaskGroup](https://www.python.jp/news/wnpython311/except-grp.html)
# [Python 3.12の新機能(その2） PEP 695: 型パラメータ文法](https://www.python.jp/news/wndpython312/pep695-type-param.html)
# [Python 3.13の新機能(その5）PEP 742: TypeIs による型の絞り込み](https://www.python.jp/news/wnpython313/pep742.html)
# [PEP 703 グローバル・インタプリタ・ロックを除去可能に の解説](https://www.python.jp/pages/no-gil/index.html)
#
# えんぶんさんの Zenn 記事
# [[詳解] Pythonのdataclasses](https://zenn.dev/enven/articles/8b80ff38461b4ff329aa)
#
# 朝日ネット 技術者ブログ
# [オブジェクト指向を5年間理解できなかった人間がオブジェクト指向を説明する(第4回)](https://techblog.asahi-net.co.jp/entry/2023/03/14/143131)
# [Python の open 関数と io モジュールをきちんと使うために](https://techblog.asahi-net.co.jp/entry/2021/10/04/162109)
#
# @mingchun_zhaoさんの Qiita 記事
# [Python I/Oの再考(1): ストリームの種類と比較検証](https://qiita.com/mingchun_zhao/items/130c802ce564822b45ce)
# [Python I/Oの再考(2): ioモジュールの高レベルインターフェース](https://qiita.com/mingchun_zhao/items/3206250501d9c8ac69e3)
# [Python I/Oの再考(3): I/Oストリームのクラス階層](https://qiita.com/mingchun_zhao/items/9d68b18a0ea2041251da)
#
# note-tech.com
# [pythonでバイナリファイルを読み込む方法[open, readinto, ctypes]](https://note-tech.com/python-binary-read/)
#
# note.nkmk.me
# [Pythonでファイルの読み込み、書き込み（作成・追記）](https://note.nkmk.me/python-file-io-open-with/)
#
# 「30歳からのプログラミング」の記事
# [ブラウザによるキャッシュの仕組み](https://numb86-tech.hatenablog.com/entry/2020/10/15/211914)
#
# 「Enlone」の記事
# [Transfer-Encoding: chunkedとHTTP/1.0の関係について](https://lonesec.com/2019/12/01/transfer-encoding/)
#
# shimakaze_softさんの Zenn 記事
# [Pythonでのメール送信](https://zenn.dev/shimakaze_soft/articles/9601818a95309c)
#
# trivial technologies の記事:
# [PythonでWeb開発入門 みんなのPython Webアプリ編 HTML版(無料)](https://coreblog.org/ats/stuff/minpy_web/)
#
# @Niiboy(niiboy)さんの Qiita 記事
# [楕円曲線と楕円曲線暗号](https://qiita.com/Niiboy/items/ec55f49ba2d4db42dcc5)
#
# Yuuki Takahashiさんの Zenn 記事
# [CSRF(Cross-Site Request Forgery)攻撃について](https://zenn.dev/yktakaha4/articles/study_csrf_attack)
#
# PCI D55 Ready Cloud の記事
# [パスキーの仕組みを分かりやすく解説 パスワードに代わる認証方法の基本的な考え方](https://pcireadycloud.com/blog/2024/03/06/5341/)
#
# @kaitolucifer(Kaito)さんの Qiita 記事
# [Pythonのthreadingとmultiprocessingを完全理解](https://qiita.com/kaitolucifer/items/e4ace07bd8e112388c75)
# [Pythonの非同期プログラミングを完全理解](https://qiita.com/kaitolucifer/items/3476158ba5bd8751e022)
#
# @ttiger55(Taiga Tachibana)さんの Qiita 記事
# [Pythonで並列処理をするなら知っておくべきGILをできる限り詳しく調べてみた](https://qiita.com/ttiger55/items/5e1d5a3405d2b3ef8f40)
#
# @yohhoyさんの Qiita 記事
# [C#でマルチスレッドのベストプラクティスって何かある？](https://qiita.com/yohhoy/items/9a4e6855dc0a2358f2ea)
#
# 猩々博士さんの note 記事
# [Python Threading Module[並列処理]についての解説](https://note.com/mega_gorilla/n/n101748d37b07)
#
# bonotakeの日記 の記事
# [『「コルーチン」とは何だったのか？』の裏話的な何か、とPythonコルーチン](https://bonotake.hatenablog.com/entry/2019/03/28/032324)
#
# PyCon JP 2021
# [実装で知るasyncio -イベントループの正体とは](https://github.com/rhoboro/events/tree/main/pycon.jp.20211016)
#
# ゆくゆくは有へと の記事
# [Pythonの非同期通信（asyncioモジュール）入門を書きました](https://iuk.hateblo.jp/entry/2017/01/27/173449)
#
# ますみ@エンジニアさんの Zenn 記事
# [サクッと始めるデータベース構築【SQL / NoSQL / newSQL】](https://zenn.dev/umi_mori/books/331c0c9ef9e5f0)
#
# 「JavaDrive」の記事
# [SQLite入門](https://www.javadrive.jp/sqlite/)
#
# 株式会社Mono Works OfficialSite のブログ記事
# [メモ：SQLiteに関するあれこれ（Datatypes）](https://monoworks.co.jp/post/android_develop_memo_2015092901/)
#
# 「kawasin73のブログ」の記事
# [SQLite のおもしろ仕様 (1) : データ型](https://kawasin73.hatenablog.com/entry/2023/09/09/200342)
#
# 「TECHSCORE BLOG」の記事
# [PostgreSQL のウィンドウ関数の使い方](https://blog.techscore.com/entry/2022/10/07/080000)
#
# オブジェクトの広場
# [事例で学ぶデザインパターン 第５回 Observer パターン ～表示と処理の分離とリアルタイム更新～](https://www.ogis-ri.co.jp/otc/hiroba/technical/DesignPatternsWithExample/chapter05.html)
#
# まんましろさんの Zenn 記事
# [pythonのlogging関連 まとめ](https://zenn.dev/re24_1986/articles/32a92b75d2bbf7)
#
# PyCon JP 2020
# [unittest.mockを使って単体テストを書こう 〜より効率的で安定したテストに〜 (みずき) [PyCon JP 2020]](https://www.youtube.com/watch?v=lQgTKHtX_xE)
#
# @odekekepeanuts さんの Qiita 記事
# [ホワイトボックステストにおけるカバレッジ（C0/C1/C2/MCC）について](https://qiita.com/odekekepeanuts/items/8b6542467d2a0066e5af)
# [テストカバレッジ100%を追求しても品質は高くならない理由と推奨されるカバレッジの目標値について](https://qiita.com/odekekepeanuts/items/d02eb38e790b93f44728)
#
# ブログ記事
# [何故オープンソースはパブリックドメインを含まないのか？](https://shujisado.com/2024/01/17/opensource-and-poublicdomain/)
#
# 「さくらのナレッジ」の記事
# [普及が進む「HTTP/2」の仕組みとメリットとは](https://knowledge.sakura.ad.jp/7734/)
#
# 「Pythonでもっと自由を」の記事
# [openpyxl](https://www.shibutan-bloomers.com/category/python/python_library/openpyxl/)
#
# CodeZine
# [NumPyで使われる多次元配列のデータ構造「ndarray」とは？](https://codezine.jp/article/detail/11211)
